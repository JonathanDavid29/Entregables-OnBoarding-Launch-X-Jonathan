# %%
nuvosPlanetas_usuarioI = ''
planetas = []

while nuvosPlanetas_usuarioI.lower() != 'Hecho':
    if nuvosPlanetas_usuarioI:
        planetas.append(nuvosPlanetas_usuarioI)
    nuvosPlanetas_usuarioI = input('Ingre un planeta ')

# %%
planetas=['Mercury','Venus','Tierra','Marte','Jupiter','Saturno','Uraneo','Neptuno']
for planet in planetas:
    print(planet)
# Out:
# Mercury
# Venus
# Tierra
# Marte
# Jupiter
# Saturno
# Uraneo
# Neptuno
