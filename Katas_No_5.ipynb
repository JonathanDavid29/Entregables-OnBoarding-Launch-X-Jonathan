# %%
Tierra = 149597870
Jupiter = 778547200

distance_km = Jupiter - Tierra
print(distance_km)

distance_mi = distance_km * 0.621
print(distance_mi)
# Out:
# 628949330
# 390577533.93

# %%
prim_planetaa= input('Introduzca la distancia del sol para el primer planeta en KM')
seg_planetaa= input('Introduzca la distancia desde el sol para el segundo planeta en KM')

prim_planetaa = int(prim_planetaa)
seg_planetaa = int(seg_planetaa)

distance_km = seg_planetaa- prim_planetaa
print(distance_km)

distance_mi = distance_km * 0.621
print(abs(distance_mi))
# Out:
# 255545555553
# 158693789998.413
