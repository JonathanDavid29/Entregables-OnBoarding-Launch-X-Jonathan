# %%
asteroide = 49
if asteroide > 25:
    print('¡Alerta! ¡Un asteroide se acerca a velocidades peligrosas!')
else:
    print('¡Sigue con tu día!')
# Out:
# ¡Alerta! ¡Un asteroide se acerca a velocidades peligrosas!

# %%
asteroide = 19
if asteroide > 20:
    print('Voltea! se acerca algo OwO')
elif asteroide == 20:
    print('Voltea! se acerca algo OwO')
else:
    print('¡Nada que ver aquí!')
# Out:
# ¡Nada que ver aquí!

# %%
vel_asteroide = 25
tam_asteroide = 40
if vel_asteroide > 25 and tam_asteroide > 25:
    print('Se acerca un asteroide muy peligroso hacia la Tierra')
elif vel_asteroide >= 20:
    print('Voltea! se mira algo en el cielo OwO')
elif tam_asteroide < 25:
    print('todo bien')
else:
    print('todo bien')
# Out:
# Voltea! se mira algo en el cielo OwO
